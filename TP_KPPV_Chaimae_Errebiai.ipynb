# %%
"""
Created on Mon Nov  8 10:53:45 2021
@author: Chaimae
"""
from sklearn.datasets import * 
import matplotlib.pyplot as plt 
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsClassifier 
from PyQt5 import QtCore, QtGui, QtWidgets
from PIL.ImageQt import ImageQt
from matplotlib.figure import Figure
from PIL import Image

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(1000, 500)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")                           
        self.pushButton = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton.setGeometry(QtCore.QRect(800, 150, 181, 31))
        self.pushButton.setObjectName("pushButton")
        self.pushButton.setStyleSheet("QPushButton{background-color : lightpink;}"
                                      "QPushButton::pressed{background-color:white;}" )        
        self.pushButton3 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton3.setGeometry(QtCore.QRect(800, 200, 181, 31))
        self.pushButton3.setObjectName("pushButton")
        self.pushButton3.setStyleSheet("QPushButton{background-color : lightpink;}"
                                      "QPushButton::pressed{background-color:white;}")
        self.ImageOrigine = QtWidgets.QLabel(self.centralwidget)
        self.ImageOrigine.setGeometry(QtCore.QRect(410, 140, 100, 100))
        self.ImageOrigine.setText("")
        self.ImageOrigine.setObjectName("label_3")      
        self.ImageOrigine.setStyleSheet("background-color:lightgrey;")
        
        self.label = QtWidgets.QLabel(self.centralwidget)
        self.label.setGeometry(QtCore.QRect(400, 50, 911, 29))
        font=QtGui.QFont()
        font.setPointSize(14)
        font.setItalic(True)
        font.setWeight(75)
        self.label.setFont(font)
        self.label.setObjectName("label")
        
        self.label_7 = QtWidgets.QLabel(self.centralwidget)
        self.label_7.setGeometry(QtCore.QRect(100, 300, 951, 231))
        self.label_7.setText(" ")
        self.label_7.setObjectName("label_7")
        font=QtGui.QFont()
        font.setPointSize(12)
        font.setItalic(True)
        font.setWeight(75)
        self.label_7.setFont(font)
        self.label_7.setObjectName("label")
        
        MainWindow.setCentralWidget(self.centralwidget)
        
        self.line = QtWidgets.QFrame(self.centralwidget)
        self.line.setGeometry(QtCore.QRect(100, 100, 800, 561))
        self.line.setFrameShape(QtWidgets.QFrame.HLine)
        self.line.setFrameShadow(QtWidgets.QFrame.Sunken)
        self.line.setObjectName("line")
            
        self.pushButton.clicked.connect(self.apprentissage)
        self.pushButton3.clicked.connect(self.image_test)
        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

    def retranslateUi(self, MainWindow):        
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "Reconnaissance des chiffres manuscrits par KNN"))               
        self.pushButton.setText(_translate("MainWindow", "Entrainement"))
        self.pushButton3.setText(_translate("MainWindow", "Choisir l'image du test"))
        self.label.setText(_translate("MainWindow", "Test KNN :"))
 
        # choix et l'affichage de l'image du test
    def image_test(self):       
        self.roll, self.done = QtWidgets.QInputDialog.getInt(
        self.centralwidget, 'Image de test', 'Entre 1347 et 1797') 
        fig = Figure(figsize=(5, 4), dpi=100)
        sc=plt.imshow(digit['images'][self.roll], cmap='Greys_r')
        image1 = Image.fromarray(np.uint8( sc.get_cmap()(sc.get_array())*255))
        if (self.done):
            qimage = ImageQt(image1)
            pixmap = QtGui.QPixmap.fromImage(qimage)
            pixmap5 = pixmap.scaled(100, 100,QtCore.Qt.KeepAspectRatio)
            self.ImageOrigine.setPixmap(pixmap5)
        pic = np.array(digit['data'][self.roll])
        picture = pic.reshape(1,-1)
    #prédiction 
        p=kppv.predict(picture)
        self.label_7.setText("C'est la forme d'un "+str(p))
            
       # entrainement du modele KPPV
    def apprentissage(self):   
        kppv.fit(x_train, y_train)
        self.label_7.setText("Apprentissage effectué, avec un taux de précision de "+str(format(kppv.score(x_test,y_test),'.3f')))
        
if __name__ == "__main__":
    import sys  
    # chargement de la base de données MNIST
    chiffres = load_digits() 
    # les images des chiffres manuscrits
    train_x = chiffres.data 
    # L'étiquetage 
    train_y =  chiffres.target 
    #découpage du jeu de données, réserver 75% des images pour l'apprentissage et le reste pour la phase du test
    x_train,x_test,y_train,y_test=train_test_split(train_x,train_y,test_size=0.25,shuffle=False)
    # création d'un modèle KPPV de 9 plus proches voisins 
    kppv = KNeighborsClassifier(9)
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
